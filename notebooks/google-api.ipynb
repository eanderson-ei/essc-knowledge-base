# %%
import pandas as pd

# %%
df = pd.read_csv('../data/outputs/essc_tags.csv', header=None)
tags = df[0].to_list()
tags
# Out:
# ['USAID',
#  'water',
#  'climate change',
#  'monitoring',
#  'biodiversity',
#  'governance',
#  'women',
#  'deforestation',
#  'livelihoods',
#  'Amazon',
#  'the United States Government',
#  'Caribbean',
#  'gender',
#  'Latin America',
#  'urban',
#  'clean energy',
#  'Colombian',
#  'REDD+',
#  'mining',
#  'fisheries',
#  'Peruvian',
#  'Mexico',
#  'Spanish',
#  'natural resource management',
#  'indigenous peoples',
#  'innovation',
#  'Africa',
#  'farming',
#  'Jamaica',
#  'Brazilian',
#  'USG',
#  'Haitian',
#  'Central America',
#  'UN',
#  'Asia',
#  'Chemonics',
#  'Ucayali',
#  'Brazil',
#  'Amazonian',
#  'English',
#  'USFS',
#  'COP',
#  'Academia',
#  'DAI',
#  'Phillipines',
#  'WWF',
#  'Forest Trends',
#  'GIS',
#  'TRAFFIC',
#  'South America',
#  'Antioquia',
#  'illegal logging',
#  'the Ministry of Environment',
#  'Congress',
#  'Program',
#  'NASA',
#  'GHG',
#  'State',
#  'private sector engagement',
#  'Europe',
#  'Tetra Tech',
#  'RE',
# ...

# %%
# print all tags over/under specified score
from __future__ import print_function
import json
import urllib

api_key = 'AIzaSyCmxQ08vh_puKJ3FL992TVbznwnrXN2qGY'

service_url = 'https://kgsearch.googleapis.com/v1/entities:search'


for tag in tags:
    query = tag
    params = {
        'query': query,
        'limit': 1,
        'indent': True,
        'key': api_key,
    }
    url = service_url + '?' + urllib.parse.urlencode(params)
    response = json.loads(urllib.request.urlopen(url).read())
    for element in response['itemListElement']:
        if element['resultScore'] < 200:
            print(tag + " | " + element['result']['name'] + ' (' + str(element['resultScore']) + ')')
# Out:
# livelihoods | Livelihoods (7)
# REDD+ | Reducing emissions from deforestation and forest degradation (61.5878791809082)
# Phillipines | The Hongkong and Shanghai Banking, Philippines Branch (59.89870071411133)
# COICA | Coordinator of Indigenous Organizations of the Amazon River Basin (9.721816062927246)
# CATIE | Catherine Lidstone (141.0422515869141)
# Caquetá | Japurá River (34.97455978393555)
# Chancay-Lambayeque | Río Chancay (6.762074947357178)
# CARICOM | CARICOM Single Market and Economy (60.08039855957031)
# Andean Amazon | Willkakuti (192.6919708251953)
# the International Center for Tropical Agriculture | International Center for Tropical Agriculture (31.01539421081543)
# SITAWI | SITAWI (7)
# the Eastern Caribbean | Eastern Time Zone (6.159931659698486)
# the Government of Colombia | Government of Colombia (20.78886604309082)
# CONAP | Cooperativa Nacional de Productores de Leche S.A. (162.8787231445312)
# ...

# %%
# print single result (or multiple results for single query)
from __future__ import print_function
import json
import urllib

api_key = 'AIzaSyCmxQ08vh_puKJ3FL992TVbznwnrXN2qGY'

service_url = 'https://kgsearch.googleapis.com/v1/entities:search'


query = "OIG"
params = {
    'query': query,
    'limit': 10,
    'indent': True,
    'key': api_key,
}
url = service_url + '?' + urllib.parse.urlencode(params)
response = json.loads(urllib.request.urlopen(url).read())
for element in response['itemListElement']:
    print(element['result']['name'] + ' (' + str(element['resultScore']) + ')')
    print(element)
# Out:
# Onion (179.5986480712891)
# {'@type': 'EntitySearchResult', 'result': {'name': 'Onion', 'description': 'Vegetable', 'detailedDescription': {'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License', 'articleBody': 'The onion, also known as the bulb onion or common onion, is a vegetable that is the most widely cultivated species of the genus Allium. Its close relatives include the garlic, scallion, shallot, leek, chive, and Chinese onion.\n', 'url': 'https://en.wikipedia.org/wiki/Onion'}, '@type': ['Thing'], '@id': 'kg:/m/0dj75'}, 'resultScore': 179.5986480712891}
# Oven (162.4857025146484)
# ...
