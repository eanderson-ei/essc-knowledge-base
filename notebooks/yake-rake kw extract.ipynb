# %%
import yake
from tika import parser
import re
import os

# %%
def read_text(f):
    """converts pdf or txt file to string"""
    _, file_extension = os.path.splitext(f)
    if file_extension == '.txt':
        with open(f, encoding="utf8") as reader:
            text = reader.read()
    elif file_extension == '.pdf':
        raw = parser.from_file(f)
        text = raw['content']
        if not text:
            print('No text found')
    else:
        print("Incorrect file extension")
    
#     # remove new lines  # NOT NEEDED WITH SPLIT/JOIN BELOW
#     text = re.sub('\n\n+', '\n\n', text)
#     text = re.sub('\n+\s\n+', '\n\n', text)  
    # drop punctuation except periods, apostrophes, and hyphens
    # (note some files use different characters than ASCII apostrophes)
    text = re.sub(r'[()/:"]', " ", text)
    # drop bullets (requires utf8 encoding)
    text = text.replace('\u2022', '')
    text = text.replace('\u2219', '')
    text = text.replace('\ufeff?', '')
    # drop periods when used in TOC, etc (i.e., multiple periods except elipsis)
    text = re.sub(r'\.\.\.\.+', '', text)  # four or more dots
    # replace elipses so it's not confused by spacy's sentence parser
    text = re.sub(r'\.\.\.', '---', text)  # three dots
    text = re.sub(r'\.\s\.\s\.\s', '---', text)  # three dots with spaces
    text = text.replace('\u2026', '---')  # elipse character
    # replace two dots
    text = re.sub(r'\.\.', '', text)  # two dots
    
    # remove excess spaces
    text = ' '.join(text.split())
    
    return text[:1000000]  # spacy nlp character limit is 1000000

# %%
report_folder = r'D:\data\essc-knowledge-base\reports_eng'

# %%
report = '04-14-Minnick-723_paper.pdf'

# %%
text = read_text(os.path.join(report_folder, report))

# %%
kw_extractor = yake.KeywordExtractor()
# text = """spaCy is an open-source software library for advanced natural language processing, written in the programming languages Python and Cython. The library is published under the MIT license and its main developers are Matthew Honnibal and Ines Montani, the founders of the software company Explosion."""
language = "en"
deduplication_threshold = 0.9
numOfKeywords = 30
custom_kw_extractor = yake.KeywordExtractor(lan=language, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
keywords = custom_kw_extractor.extract_keywords(text)
for kw in keywords:
    print(kw)
# Out:
# ('scenario gregory minnick', 0.0004760500127513386)
# ('gold', 0.001556957971529783)
# ('antioquia asgm operators', 0.005657256687719865)
# ('small-scale', 0.013614461744106172)
# ('bgi', 0.02040323062924821)
# ('key', 0.0706393236716569)
# ('eia', 0.10229885591651727)
# ('mpu', 0.11078386897942487)
# ('due', 0.13961465996933056)
# ('projekt-consult gmbh', 0.23282441769080334)
# ('16-20', 0.43457390939012097)
# ('n’t', 0.4353449597600033)
# ('iván', 0.5868716588242664)
# ('paz', 0.6046274344464135)
# ('flow', 0.8630308175829986)

# %%
from rake_nltk import Rake
rake_nltk_var = Rake()
# text = """spaCy is an open-source software library for advanced natural language processing,
# written in the programming languages Python and Cython. The library is published under the MIT license
# and its main developers are Matthew Honnibal and Ines Montani, the founders of the software company Explosion."""
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
print(keyword_extracted)
# Out:
# ['estudio de la cadena del mercurio en colombia con énfasis en la actividad minera de oro', 'consulta con grupos de interés para una propuesta', 'plan nacional de desarrollo 2018 – 2022 pacto por colombia', 'government identifies 29 “ mercury hot spots ” located', 'la política de formalización minera de oro', '7 “ neutral stakeholder ,” neither expanding', 'small miners asm source swiss better gold association figure 2', 'expand asgm formalization national unified formalization plan nufp', 'national unified formalization plan nufp whose objective', 'mostly female subsistence “ barequeros ” benefit', 'swiss better gold association continuous improvement escalator', '“ oro legal ” activity supports asgm operators', '11 mining formalization projects comprising 135 mpus', 'asociación de agromineros del cauca alone', 'references agencia nacional minera anc', 'vulnerable populations hentschel et al ., 2002', 'censo minero departamental 2010 – 2011', 'thomas hentschel chemonics inc ., projekt', 'partir de la percepción remota', 'national development plan 2018 – 2022', 'explotación de oro de aluvión', '“ oro legal ” activity responds', '“ barequeras ” report paltry returns', '357 mining production units mpus recorded', 'illegal gold mining also finances illegal groups', 'internationally recognized due diligence system implemented', 'sbga better gold “ escalator ”', 'incentive programs like international responsible gold initiatives', 'estudio nacional del agua', 'consensus emerged across stakeholder groups around', 'isolated flood plains offer good conditions', 'getting worse ,” world political review', 'economic development securing licit economic growth', '“ special reserve area ” pathway', 'specific recipients special mining reserve areas', 'pacto por la equidad', 'regional autonomous corporations departmental environmental authorities', 'asgm cordy et al ., 2011', 'colombian minimum monthly wage approximately us', '“ de facto ” routes', 'internally accepted due diligence processes', '“ asgm service centers ”', 'largest mercury polluter per capita', 'highest per capita mercury pollution', 'alluvial mining without restricting titleholder ’', 'many remote mining areas like chocó', '“ special reserve areas ”', '“ oro legal ” activity', 'later conduct hard rock mining', 'swiss better gold association sbga', 'spanish acronyms – would raise', 'government must conduct necessary geological', 'brings together individual gold panners', 'poorly educated miners avoid exploitation', 'aquatic food chains affecting wildlife', 'several “ sting ” operations', 'varied perspectives across different sectors', 'development oecd due diligence guidance', '“ traditional mining ” reassessed', 'colombia results 2016 – 2018', 'need support across several fronts', 'united nations environmental programme unep', '“ 2020 world bank conference', 'national unified formalization plan', 'local asgm operators increasingly organize', 'generating significant positive multiplier effects', 'asgm operators see figure 2', 'based international gold trader exporting', 'readers may make verbatim copies', 'less costly mine operating plans ptos', '17 technical specialists including biologists', 'mining census includes extractive activities', 'recently approved special concessions contract', 'brought 500 subsistence gold panners', 'illegal operators using heavy machinery', 'required mineral commercialization permits according', 'roughly 500 mainly female panners', 'reducing mining activity per se', 'manage 11 honey production projects', 'asgm “ value chain ,”', 'exhaustive environmental control ironically results', 'increasingly prevalent informal economic activity', 'total gold mining operations nationwide', 'volumen por departamento anual', 'environmental impact studies eias –', 'swiss better gold association', 'oecd due diligence guidance', 'asm program – 18 years', 'universidad externado de colombia', 'use heavy mechanized equipment .”', 'public policy context per se', 'fich ...
